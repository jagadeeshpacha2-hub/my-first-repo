# %% [markdown]
# What is the difference between hardware and software? Give one example of each. - A hardware is a physical component of computer that enable process all the commands. while a software is a commands written in Highlevel language or machine level language that achieve specific task
